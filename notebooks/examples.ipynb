# %%
# %reload_ext autoreload
# %autoreload 2
import colabexts
from colabexts.jcommon import *

jpath=os.path.dirname(colabexts.__file__)
jcom = f'{jpath}/jcommon.ipynb'
# %run $jcom
# Out:
# <textarea rows=5 id=nav_head_content style="width:100%;display:none;">
# <style>
# a.bh,  a.bh:visited, a.bh:link, a.bh:active {
#   ttext-decoration: none;
#   color: black;
#   font-family: 'Roboto','Heebo',Arial,sans-serif;
#   font-size: 3em
# }
# </style>
# <!--
# <div id='HTMLTopBar' style="
#     z-index: 50;
#     align-items: stretch;
#     width:100%">
#     <div  style="
#         text-color: black;
#         background-color: #fefefe;
#         bborder-bottom: 1px dotted gray;
#         padding-left: 2px;
#         box-shadow: 5px 1px #ccc;
#         height: 40px; left: 0;
#         padding: 14px;
#         "
#     >
#     <a class=bh1 href="#" onclick="$('#maintoolbar').toggle();">X</a>
# </div>
# -->
# <style>
#
# </style>
# </textarea>
#
#
# <script>
# if ($('#nav_head').length < 1) {
#     $('#notebook-container').prepend('<div id="nav_head" style="width:100%;">.</div>')
#     console.log("Added a div")
# } else{
#     console.log("Already Added")
# }
#
# ...

# %%
from itertools import chain, combinations

def powerset(iterable):
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(len(s)+1))

def wilcoxonCriticalValues(alpha= 0.05, n = 10, log = True):
    m = 2**n -1# maxsum= n * (n-1)/2
    s = defaultdict(int)
    for i in powerset(range(1,n+1)):
        sm = sum(i)
        if (not sm):
            continue
        s[sm] +=1

    cr1, cr2, c = 0, 0, 0 
    for k in sorted(s.keys()):
        p  = s[k]/m
        c += p
        c= round(c, 3)
        if ( not cr1 and c > alpha):
            cr1 = k-1
            print(f'{c: 9.6}', end =" ")
        if ( not cr2 and 2*c > alpha):
            cr2 = k-1

        if (log):
            print( f'Key: {k:3} p: {round(p,4): 8.4} Cum: {round(c,4):8.5}, alpha: {alpha} 1-tail: {cr1:3} 2-tail{cr2:3} Max-Sum: {m}')
        if ( cr1 and cr2):
            break
            
    return alpha, cr1, cr2
    
alpha = 0.05
for n in range(5,20):
    a, cr1, cr2 = wilcoxonCriticalValues(0.05, n, False)
    print( f'alpha: {alpha} n: {n:3} 1-tail: {cr1:3} 2-tail{cr2:3} ')
# Out:
#     0.064 alpha: 0.05 n:   5 1-tail:   1 2-tail  1
#     0.064 alpha: 0.05 n:   6 1-tail:   2 2-tail  1
#     0.072 alpha: 0.05 n:   7 1-tail:   4 2-tail  2
#     0.052 alpha: 0.05 n:   8 1-tail:   5 2-tail  4
#     0.064 alpha: 0.05 n:   9 1-tail:   8 2-tail  5
#     0.053 alpha: 0.05 n:  10 1-tail:  10 2-tail  8
#      0.06 alpha: 0.05 n:  11 1-tail:  14 2-tail 11
#     0.054 alpha: 0.05 n:  12 1-tail:  17 2-tail 14
#     0.054 alpha: 0.05 n:  13 1-tail:  21 2-tail 17
#     0.051 alpha: 0.05 n:  14 1-tail:  25 2-tail 21
#     0.052 alpha: 0.05 n:  15 1-tail:  30 2-tail 25
#     0.052 alpha: 0.05 n:  16 1-tail:  35 2-tail 30
#     0.052 alpha: 0.05 n:  17 1-tail:  41 2-tail 35
#     0.052 alpha: 0.05 n:  18 1-tail:  47 2-tail 41
#     0.055 alpha: 0.05 n:  19 1-tail:  54 2-tail 47

# %%
import 
if ( os.path.exists(upapp) and os.path.exists(f"{upapp}/application_context/") ):
